# %% [markdown]
# # Marine Protected Areas

# %%
from pathlib import Path

import geopandas as gpd

# %%
INPUT_DIR = Path("../../data/raw/mpa")
INPUT_FILE = INPUT_DIR / "mpa_inventory.parquet"

# %%
mpa_df = gpd.read_parquet(INPUT_FILE)
mpa_df.describe()
# Out:
#          OBJECTID    Estab_Yr  IUCN_MPA       WDPA_Cd        AreaKm  \
# count  843.000000   843.00000     843.0  8.430000e+02    843.000000
# mean   490.558719  1857.26809       1.0  1.794001e+08    170.567627
# std    287.131674   481.91735       0.0  2.591348e+08   1024.533325
# min      2.000000     0.00000       1.0  0.000000e+00      0.000828
# 25%    235.500000  1966.00000       1.0  0.000000e+00      0.755693
# 50%    493.000000  1983.00000       1.0  3.124260e+05      6.336530
# 75%    737.500000  1999.00000       1.0  5.555860e+08     33.279751
# max    979.000000  2022.00000       1.0  5.555870e+08  15825.700195
#
#             AreaMar  MarPercent      AreaNT   Longitude    Latitude  \
# count    843.000000  843.000000  843.000000  843.000000  843.000000
# mean     139.355024   53.896797    4.931544  -94.615151   35.567010
# std      994.170245   42.230338   30.431341   20.721137    7.012971
# min        0.000000    0.000000    0.000000 -124.882834    0.000000
# ...

# %%
mpa_df.head()
# Out:
#    OBJECTID Site_ID                                          Site_Name  \
# 1         2   NPS10                    Cape Hatteras National Seashore
# 3         4     CT1       Bluff Point State Park/Natural Area Preserve
# 4         5    CT10  Silver Sands State Park/Charles Island Natural...
# 5         6    CT12               Barn Island Wildlife Management Area
# 6         7    CT14         Charles E. Wheeler Wildlife Mangement Area
#
#   Gov_Level State              Prot_Lvl  \
# 1   Federal    NC  Uniform Multiple Use
# 3     State    CT    Zoned Multiple Use
# 4     State    CT    Zoned Multiple Use
# 5     State    CT  Uniform Multiple Use
# 6     State    CT  Uniform Multiple Use
#
#                                            Mgmt_Agen  \
# 1                              National Park Service
# 3  Connecticut Department of Environmental Protec...
# 4  Connecticut Department of Environmental Protec...
# 5  Connecticut Department of Environmental Protec...
# ...

# %%
mpa_df.columns
# Out:
# Index(['OBJECTID', 'Site_ID', 'Site_Name', 'Gov_Level', 'State', 'Prot_Lvl',
#        'Mgmt_Agen', 'Mgmt_Plan', 'Pri_Con_Fo', 'Cons_Focus', 'Fish_Rstr',
#        'Prot_Focus', 'Permanence', 'Constancy', 'Estab_Yr', 'Anchor', 'Vessel',
#        'IUCN_MPA', 'IUCNcat', 'Category', 'Marine', 'URL', 'WDPA_Cd',
#        'ProSeasID', 'Design', 'AreaKm', 'AreaMar', 'MarPercent', 'AreaNT',
#        'Longitude', 'Latitude', 'VxCount', 'SHAPE_Leng', 'SHAPE_Length',
#        'SHAPE_Area', 'geometry'],
#       dtype='str')

# %%
mpa_df[mpa_df.Marine == "Marine"].Category.value_counts()
# Out:
# Category
# IUCN MPA    290
# Name: count, dtype: int64

# %%
mpa_df.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
print(mpa_df["State"].value_counts())
# Out:
# State
# FL              215
# CA              196
# WA               64
# NC               44
# OR               32
# VA               28
# NJ               26
# NY               25
# CT               22
# TX               22
# GA               20
# MA               20
# MI               18
# MS               18
# SC               15
# DE               10
# ME                9
# LA                8
# OH                8
# RI                6
# MD                6
# NH                5
# MN                4
# WI                4
# PA                3
# IL                2
# IN                2
# AL                2
# AL, MS            1
# FL, MS            1
# VA, MD            1
# OR, WA            1
# NC, VA            1
# NJ, NY            1
# US-MI, CA-ON      1
# GA, SC            1
# TX, LA            1
# Name: count, dtype: int64
